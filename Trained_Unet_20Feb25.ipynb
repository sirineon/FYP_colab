# %% [markdown]
# <a href="https://colab.research.google.com/github/sirineon/FYP_colab/blob/main/Trained_Unet_20Feb25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install octave -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn default-jre-headless epstool fonts-droid-fallback fonts-freefont-otf fonts-noto-mono
#   fonts-urw-base35 ghostscript gnuplot-data gnuplot-qt gsfonts imagemagick-6-common info
#   install-info libamd2 libauthen-sasl-perl libbtf1 libcamd2 libccolamd2 libcholmod3 libclone-perl
#   libcolamd2 libcombblas1.16.0 libcxsparse3 libdata-dump-perl libemf1 libencode-locale-perl
#   libevdev2 libfftw3-double3 libfftw3-long3 libfftw3-mpi3 libfftw3-single3 libfile-listing-perl
#   libfltk-gl1.3 libfltk1.3 libfont-afm-perl libglpk40 libglu1-mesa libgraphicsmagick++-q16-12
#   libgraphicsmagick-q16-3 libgs9 libgs9-common libgudev-1.0-0 libhdf5-openmpi-103-1
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
# ...

# %%
# Try to add a matlab (.m) file
# %%writefile add.m
x = 3
y = 2
display(x+y)
# Out:
# Writing add.m

# %%
# to read the result written in file add.m
# -W : no window system
# !octave -W add.m
# Out:
# x = 3
# y = 2
# 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# test if data path is correct by editing path below
# !ls /content/drive/MyDrive/u-net-release-2015-10-02/u-net-release/
# Out:
# caffe_cpu	lib			  phseg_v5-train.prototxt  tmp-test.prototxt
# caffe_gpu	mycaffe_tiled_forward5.m  README.txt		   trackCells2.m
# caffe-unet-src	PhC-C2DH-U373		  segmentAndTrack2.m	   Trained_Unet_20Feb25.ipynb
# Copyright.txt	phseg_v5.caffemodel	  segmentAndTrack.sh

# %%
# give shell (.sh) file execute permissions
# !chmod +x /content/drive/MyDrive/u-net-release-2015-10-02/u-net-release/segmentAndTrack.sh

# %%
# run shell script
# !sh /content/drive/MyDrive/u-net-release-2015-10-02/u-net-release/segmentAndTrack.sh
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# ...
#     segmentAndTrack2 at line 63 column 8
#
# error: paddedFullVolume(185,_,_): out of bound 184 (dimensions are 184x184)
# error: called from
#     mycaffe_tiled_forward5 at line 30 column 35
#     segmentAndTrack2 at line 63 column 8

# %%
# !pwd  # Check the current directory, if >>"/content" is displayed, the directory is correct
# Out:
# /content
