# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/constantinpape/torch-em/blob/main/experiments/2D-UNet-Training.ipynb)

# %% [markdown]
# # 2D UNet Training
#
# This notebook implements training of a 2D UNet with `torch_em`. It implements training for affinity, boundary and foreground prediction. The training code is also customizable to enable training with a different target.
#
# The sections of this notebook are organized s.t. there is a first cell that contains the configurable parameters. These cells are marked by the comment `#CONFIGURE ME`. The following cells contain code that do not need to be changed. But if you know what you're doing you can further customize the training there.
#
# For setting up a local environment that can run `torch_em`, follow [the installation instructions](https://github.com/constantinpape/torch-em#installation). You can also run the notebook in google colab, please follow the instructions in the first section for this.

# %% [markdown]
# ## Google Colab
#
# Run the following cells if you are working in google colab. Skip them otherwise.

# %%
# First, make sure that you are using a GPU. For this, go to:
# Runtime->Change runtime type and select Hardware accelarator->GPU
# When you then run this cell you should see a gpu status overview
# (if something went wrong you will see an error message)
# !nvidia-smi
# Out:
# Mon Jan 13 18:09:47 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Install conda in your google drive session
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# update conda
# !conda update conda
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     openssl-3.4.0              |       h7b32b05_1         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.12.14-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.12.14-pyhd8ed1ab_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.2.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.2.0-h77fa898_1
#   openssl                                  3.2.0-hd590300_1 --> 3.4.0-h7b32b05_1
#
#
#
# Downloading and Extracting Packages:
# openssl-3.4.0        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-14.2.0        | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libgomp-14.2.0       | 450 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# certifi-2024.12.14   | 158 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ca-certificates-2024 | 153 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :   1% 0.005578181357625296/1 [00:00<00:30, 31.06s/it]
# libgcc-14.2.0        | 829 KB    | :   2% 0.019303795604097816/1 [00:00<00:09,  9.22s/it]
#
# libgomp-14.2.0       | 450 KB    | :   4% 0.0355407469110093/1 [00:00<00:05,  5.45s/it]
#
#
#
# ca-certificates-2024 | 153 KB    | :  10% 0.10429822774495824/1 [00:00<00:01,  1.91s/it]
#
#
# openssl-3.4.0        | 2.8 MB    | :  61% 0.6135999493387826/1 [00:00<00:00,  2.76it/s]
#
#
#
# ca-certificates-2024 | 153 KB    | : 100% 1.0/1 [00:00<00:00,  1.91s/it]
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | :  30% 0.3026116508440767/1 [00:00<00:00,  1.06s/it]
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
#
#
# certifi-2024.12.14   | 158 KB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
#
# certifi-2024.12.14   | 158 KB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:00<00:00,  2.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# use conda to install torch-em dependencies (we don't install torch-em itseelf, in order to avoid reinstallation of pytorch)
# !conda install -c pytorch -c conda-forge python-elf dask bioimageio.core
# Out:
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bioimageio.core
#     - dask
#     - python-elf
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     affogato-0.3.3             |  py310hcc13569_3         359 KB  conda-forge
#     annotated-types-0.7.0      |     pyhd8ed1ab_1          18 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     aws-c-auth-0.7.11          |       h0b4cabd_1         101 KB  conda-forge
#     aws-c-cal-0.6.9            |       h14ec70c_3          54 KB  conda-forge
#     aws-c-common-0.9.12        |       hd590300_0         220 KB  conda-forge
#     aws-c-compression-0.2.17   |       h572eabf_8          19 KB  conda-forge
#     aws-c-event-stream-0.4.1   |       h97bb272_2          53 KB  conda-forge
#     aws-c-http-0.8.0           |       h9129f04_2         190 KB  conda-forge
#     aws-c-io-0.14.0            |       hf8f278a_1         153 KB  conda-forge
#     aws-c-mqtt-0.10.1          |       h2b97f5f_0         160 KB  conda-forge
#     aws-c-s3-0.4.9             |       hca09fc5_0         103 KB  conda-forge
#     aws-c-sdkutils-0.1.13      |       h572eabf_1          52 KB  conda-forge
#     aws-checksums-0.1.17       |       h572eabf_7          49 KB  conda-forge
#     aws-crt-cpp-0.26.0         |       h04327c0_8         326 KB  conda-forge
#     aws-sdk-cpp-1.11.210       |      hba3e011_10         3.4 MB  conda-forge
#     bioimageio.core-0.7.0      |     pyhd8ed1ab_1          64 KB  conda-forge
#     bioimageio.spec-0.5.3.5    |     pyhff2d567_0         140 KB  conda-forge
#     blosc-1.21.5               |       h0f2a231_0          48 KB  conda-forge
#     bokeh-3.6.2                |     pyhd8ed1ab_1         4.6 MB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     brunsli-0.1                |       h9c3ff4c_0         200 KB  conda-forge
#     c-blosc2-2.14.3            |       hb4ffafa_0         329 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cairo-1.18.0               |       h3faef2a_0         959 KB  conda-forge
#     charls-2.4.2               |       h59595ed_0         147 KB  conda-forge
#     click-8.1.8                |     pyh707e725_0          83 KB  conda-forge
#     cloudpickle-3.1.0          |     pyhd8ed1ab_2          25 KB  conda-forge
#     coin-or-cbc-2.10.12        |       h8b142ea_1         928 KB  conda-forge
#     coin-or-cgl-0.60.7         |       h516709c_0         538 KB  conda-forge
#     coin-or-clp-1.17.8         |       h1ee7a9c_0         1.1 MB  conda-forge
#     coin-or-osi-0.108.10       |       haf5fa05_0         364 KB  conda-forge
#     coin-or-utils-2.11.11      |       hee58242_0         672 KB  conda-forge
#     coincbc-2.10.12            |    1_metapackage          12 KB  conda-forge
#     contourpy-1.3.1            |  py310h3788b33_0         255 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     cytoolz-1.0.1              |  py310ha75aee5_0         359 KB  conda-forge
#     dask-2024.12.1             |     pyhd8ed1ab_0           7 KB  conda-forge
#     dask-core-2024.12.1        |     pyhd8ed1ab_0         885 KB  conda-forge
#     dask-expr-1.1.21           |     pyhd8ed1ab_0         181 KB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     distributed-2024.12.1      |     pyhd8ed1ab_0         785 KB  conda-forge
#     dnspython-2.6.1            |     pyhd8ed1ab_1         165 KB  conda-forge
#     docstring_parser-0.16      |     pyhd8ed1ab_0          30 KB  conda-forge
#     email-validator-2.2.0      |     pyhd8ed1ab_1          43 KB  conda-forge
#     email_validator-2.2.0      |       hd8ed1ab_1           6 KB  conda-forge
#     et_xmlfile-2.0.0           |     pyhd8ed1ab_1          21 KB  conda-forge
#     expat-2.6.4                |       h5888daf_0         135 KB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.55.3           |  py310h89163eb_1         2.2 MB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     fsspec-2024.12.0           |     pyhd8ed1ab_0         135 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     gettext-0.22.5             |       he02047a_3         468 KB  conda-forge
#     gettext-tools-0.22.5       |       he02047a_3         2.6 MB  conda-forge
#     gflags-2.2.2               |    h5888daf_1005         117 KB  conda-forge
#     giflib-5.2.2               |       hd590300_0          75 KB  conda-forge
#     glog-0.6.0                 |       h6f12383_0         112 KB  conda-forge
#     glpk-5.0                   |       h445213a_0        1023 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     graphviz-9.0.0             |       h78e8752_1         2.2 MB  conda-forge
#     gtk2-2.24.33               |       h280cfa0_4         6.2 MB  conda-forge
#     gts-0.7.6                  |       h977cf35_4         311 KB  conda-forge
#     h5py-3.12.1                |nompi_py310h60e0fe6_103         1.2 MB  conda-forge
#     harfbuzz-8.5.0             |       hfac3d4d_0         1.5 MB  conda-forge
#     hdf5-1.14.3                |nompi_h4f84152_100         3.7 MB  conda-forge
#     imagecodecs-2024.1.1       |  py310h68afbfc_3         2.0 MB  conda-forge
#     imageio-2.36.1             |     pyh12aca89_1         286 KB  conda-forge
#     imath-3.1.11               |       hfc55251_0         159 KB  conda-forge
#     importlib-metadata-8.5.0   |     pyha770c72_1          28 KB  conda-forge
#     jinja2-3.1.5               |     pyhd8ed1ab_0         110 KB  conda-forge
#     joblib-1.4.2               |     pyhd8ed1ab_1         215 KB  conda-forge
#     jxrlib-1.1                 |       hd590300_3         234 KB  conda-forge
#     kiwisolver-1.4.7           |  py310h3788b33_0          70 KB  conda-forge
#     lazy-loader-0.4            |     pyhd8ed1ab_2          16 KB  conda-forge
#     lazy_loader-0.4            |     pyhd8ed1ab_2           7 KB  conda-forge
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     lemon-1.3.1                |       h6169397_8         3.1 MB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libabseil-20230802.1       | cxx17_h59595ed_0         1.2 MB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
#     libarrow-15.0.0            |   h84dd17c_0_cpu        22.0 MB  conda-forge
#     libarrow-acero-15.0.0      |   h59595ed_0_cpu         582 KB  conda-forge
#     libarrow-dataset-15.0.0    |   h59595ed_0_cpu         570 KB  conda-forge
#     libarrow-flight-15.0.0     |   h120cb0d_0_cpu         488 KB  conda-forge
#     libarrow-flight-sql-15.0.0 |   h61ff412_0_cpu         189 KB  conda-forge
#     libarrow-gandiva-15.0.0    |   hacb8726_0_cpu         874 KB  conda-forge
#     libarrow-substrait-15.0.0  |   h61ff412_0_cpu         497 KB  conda-forge
#     libasprintf-0.22.5         |       he8f35ee_3          42 KB  conda-forge
#     libasprintf-devel-0.22.5   |       he8f35ee_3          33 KB  conda-forge
#     libavif16-1.1.1            |       h1909e37_2         113 KB  conda-forge
#     libblas-3.9.0              |26_linux64_openblas          16 KB  conda-forge
#     libboost-1.82.0            |       h6fcfa73_6         2.5 MB  conda-forge
#     libboost-python-1.82.0     |  py310hcb52e73_6         116 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd590300_1          68 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd590300_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd590300_1         276 KB  conda-forge
#     libcblas-3.9.0             |26_linux64_openblas          16 KB  conda-forge
#     libcrc32c-1.1.2            |       h9c3ff4c_0          20 KB  conda-forge
#     libdeflate-1.20            |       hd590300_0          70 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libexpat-2.6.4             |       h5888daf_0          72 KB  conda-forge
#     libgd-2.3.3                |       h119a65a_9         219 KB  conda-forge
#     libgettextpo-0.22.5        |       he02047a_3         167 KB  conda-forge
#     libgettextpo-devel-0.22.5  |       he02047a_3          36 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_1          53 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_1          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hd5240d6_1         1.4 MB  conda-forge
#     libglib-2.80.2             |       hf974151_0         3.7 MB  conda-forge
#     libgoogle-cloud-2.12.0     |       h5206363_4        41.5 MB  conda-forge
#     libgrpc-1.59.3             |       hd6c4280_0         6.3 MB  conda-forge
#     libhwy-1.1.0               |       h00ab1b0_0         1.1 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     libjxl-0.10.3              |       h66b40c8_0         1.5 MB  conda-forge
#     liblapack-3.9.0            |26_linux64_openblas          16 KB  conda-forge
#     liblapacke-3.9.0           |26_linux64_openblas          16 KB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     libllvm15-15.0.7           |       hb3ce162_4        31.8 MB  conda-forge
#     libnl-3.11.0               |       hb9d3cd8_0         724 KB  conda-forge
#     libopenblas-0.3.28         |pthreads_h94d23a6_1         5.3 MB  conda-forge
#     libparquet-15.0.0          |   h352af49_0_cpu         1.1 MB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libprotobuf-4.24.4         |       hf27288f_0         2.4 MB  conda-forge
#     libre2-11-2023.09.01       |       h7a70373_1         227 KB  conda-forge
#     librsvg-2.56.3             |       he3f83f7_1         5.6 MB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libthrift-0.19.0           |       hb90f79a_1         400 KB  conda-forge
#     libtiff-4.6.0              |       h1dd3fc0_3         276 KB  conda-forge
#     libutf8proc-2.8.0          |       hf23e847_1          79 KB  conda-forge
#     libwebp-1.4.0              |       h2c329e2_0          90 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.15                |       h0b41bf4_0         375 KB  conda-forge
#     libzopfli-1.0.3            |       h9c3ff4c_0         164 KB  conda-forge
#     llvmlite-0.42.0            |  py310h1b8f574_1         3.2 MB  conda-forge
#     locket-1.0.0               |     pyhd8ed1ab_0           8 KB  conda-forge
#     loguru-0.7.2               |  py310hff52083_2          96 KB  conda-forge
#     lz4-4.3.3                  |  py310hb259640_1          36 KB  conda-forge
#     magicgui-0.9.1             |     pyhd8ed1ab_1          94 KB  conda-forge
#     markdown-it-py-3.0.0       |     pyhd8ed1ab_1          63 KB  conda-forge
#     markupsafe-3.0.2           |  py310h89163eb_1          23 KB  conda-forge
#     matplotlib-base-3.10.0     |  py310h68603db_0         7.1 MB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_1          14 KB  conda-forge
#     mrcfile-1.5.3              |     pyhd8ed1ab_1          38 KB  conda-forge
#     msgpack-python-1.1.0       |  py310h3788b33_0          96 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     networkx-3.4.2             |     pyh267e887_2         1.2 MB  conda-forge
#     nifty-1.2.1                |  py310h16739e1_4         4.2 MB  conda-forge
#     numba-0.59.1               |  py310h7dc5dd1_0         4.1 MB  conda-forge
#     numpy-1.26.4               |  py310hb13e2d6_0         6.7 MB  conda-forge
#     openexr-3.2.2              |       haf962dd_1         1.4 MB  conda-forge
#     openjpeg-2.5.2             |       h488ebb8_0         334 KB  conda-forge
#     openpyxl-3.1.5             |  py310h0999ad4_1         590 KB  conda-forge
#     orc-1.9.2                  |       h4b38347_0         994 KB  conda-forge
#     pandas-2.2.3               |  py310h5eaa309_1        12.4 MB  conda-forge
#     pango-1.54.0               |       h84a9a3c_0         438 KB  conda-forge
#     partd-1.4.2                |     pyhd8ed1ab_0          20 KB  conda-forge
#     pcre2-10.43                |       hcad00b1_0         929 KB  conda-forge
#     pillow-10.3.0              |  py310hf73ecf8_0        39.8 MB  conda-forge
#     pixman-0.44.2              |       h29eaf8c_0         372 KB  conda-forge
#     pooch-1.8.2                |     pyhd8ed1ab_1          53 KB  conda-forge
#     psutil-6.1.1               |  py310ha75aee5_0         360 KB  conda-forge
#     psygnal-0.11.1             |     pyhd8ed1ab_1          62 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyarrow-15.0.0             |py310hf9e7431_0_cpu         4.3 MB  conda-forge
#     pyconify-0.2               |     pyhd8ed1ab_0          22 KB  conda-forge
#     pydantic-2.10.5            |     pyh3cfb1c2_0         290 KB  conda-forge
#     pydantic-core-2.27.2       |  py310h505e2c1_0         1.6 MB  conda-forge
#     pydantic-settings-2.7.1    |     pyh3cfb1c2_0          31 KB  conda-forge
#     pygments-2.19.1            |     pyhd8ed1ab_0         868 KB  conda-forge
#     pyparsing-3.2.1            |     pyhd8ed1ab_0          91 KB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhff2d567_1         217 KB  conda-forge
#     python-dotenv-1.0.1        |     pyhd8ed1ab_1          24 KB  conda-forge
#     python-elf-0.6.0           |     pyhd8ed1ab_1         221 KB  conda-forge
#     python-tzdata-2024.2       |     pyhd8ed1ab_1         139 KB  conda-forge
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     pywavelets-1.8.0           |  py310hf462985_0         3.5 MB  conda-forge
#     pyyaml-6.0.2               |  py310ha75aee5_1         178 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     qtpy-2.4.2                 |     pyhd8ed1ab_1          61 KB  conda-forge
#     rav1e-0.6.6                |       he8a937b_2        14.7 MB  conda-forge
#     rdma-core-54.0             |       h5888daf_0         4.5 MB  conda-forge
#     re2-2023.09.01             |       h7f4b329_1          26 KB  conda-forge
#     rich-13.9.4                |     pyhd8ed1ab_1         181 KB  conda-forge
#     ruyaml-0.91.0              |     pyhd8ed1ab_1          87 KB  conda-forge
#     s2n-1.4.1                  |       h06160fa_0         324 KB  conda-forge
#     scikit-image-0.25.0        |  py310h5eaa309_1        10.3 MB  conda-forge
#     scikit-learn-1.6.1         |  py310h27f47ee_0         9.0 MB  conda-forge
#     scipy-1.15.1               |  py310hfa6ec8c_0        17.6 MB  conda-forge
#     six-1.17.0                 |     pyhd8ed1ab_0          16 KB  conda-forge
#     skan-0.12.1                |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     snappy-1.1.10              |       hdb0a2a9_1          39 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_1          15 KB  conda-forge
#     sortedcontainers-2.4.0     |     pyhd8ed1ab_0          26 KB  conda-forge
#     superqt-0.7.0              |     pyhb6d5dde_0          72 KB  conda-forge
#     svt-av1-2.3.0              |       h5888daf_0         2.6 MB  conda-forge
#     tblib-3.0.0                |     pyhd8ed1ab_1          17 KB  conda-forge
#     threadpoolctl-3.5.0        |     pyhc1e730c_0          23 KB  conda-forge
#     tifffile-2024.12.12        |     pyhd8ed1ab_0         177 KB  conda-forge
#     toolz-1.0.0                |     pyhd8ed1ab_1          51 KB  conda-forge
#     tornado-6.4.2              |  py310ha75aee5_0         635 KB  conda-forge
#     typing-extensions-4.12.2   |       hd8ed1ab_1          10 KB  conda-forge
#     typing_extensions-4.12.2   |     pyha770c72_1          39 KB  conda-forge
#     ucx-1.15.0                 |       ha691c75_8         6.5 MB  conda-forge
#     unicodedata2-16.0.0        |  py310ha75aee5_0         395 KB  conda-forge
#     vigra-1.11.2               |  py310h53e871b_5         6.7 MB  conda-forge
#     wrapt-1.17.1               |  py310ha75aee5_0          55 KB  conda-forge
#     xarray-2025.1.1            |     pyhd8ed1ab_0         814 KB  conda-forge
#     xorg-kbproto-1.0.7         |    hb9d3cd8_1003          30 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.5           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.9          |       h8ee46fc_0         809 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxrender-0.9.11     |       hd590300_0          37 KB  conda-forge
#     xorg-renderproto-0.11.1    |    hb9d3cd8_1003          12 KB  conda-forge
#     xorg-xextproto-7.3.0       |    hb9d3cd8_1004          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    hb9d3cd8_1008          72 KB  conda-forge
#     xyzservices-2024.9.0       |     pyhd8ed1ab_1          46 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     z5py-2.0.17                |  py310h1a603b2_0         568 KB  conda-forge
#     zfp-1.0.1                  |       h5888daf_2         273 KB  conda-forge
#     zict-3.0.0                 |     pyhd8ed1ab_1          35 KB  conda-forge
#     zipp-3.21.0                |     pyhd8ed1ab_1          21 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     zlib-ng-2.0.7              |       h0b41bf4_0          92 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       402.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   affogato           conda-forge/linux-64::affogato-0.3.3-py310hcc13569_3
#   annotated-types    conda-forge/noarch::annotated-types-0.7.0-pyhd8ed1ab_1
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-h04ea711_2
#   aws-c-auth         conda-forge/linux-64::aws-c-auth-0.7.11-h0b4cabd_1
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.6.9-h14ec70c_3
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.9.12-hd590300_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.2.17-h572eabf_8
#   aws-c-event-stream conda-forge/linux-64::aws-c-event-stream-0.4.1-h97bb272_2
#   aws-c-http         conda-forge/linux-64::aws-c-http-0.8.0-h9129f04_2
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.14.0-hf8f278a_1
#   aws-c-mqtt         conda-forge/linux-64::aws-c-mqtt-0.10.1-h2b97f5f_0
#   aws-c-s3           conda-forge/linux-64::aws-c-s3-0.4.9-hca09fc5_0
#   aws-c-sdkutils     conda-forge/linux-64::aws-c-sdkutils-0.1.13-h572eabf_1
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.1.17-h572eabf_7
#   aws-crt-cpp        conda-forge/linux-64::aws-crt-cpp-0.26.0-h04327c0_8
#   aws-sdk-cpp        conda-forge/linux-64::aws-sdk-cpp-1.11.210-hba3e011_10
#   bioimageio.core    conda-forge/noarch::bioimageio.core-0.7.0-pyhd8ed1ab_1
#   bioimageio.spec    conda-forge/noarch::bioimageio.spec-0.5.3.5-pyhff2d567_0
#   blosc              conda-forge/linux-64::blosc-1.21.5-h0f2a231_0
#   bokeh              conda-forge/noarch::bokeh-3.6.2-pyhd8ed1ab_1
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   brunsli            conda-forge/linux-64::brunsli-0.1-h9c3ff4c_0
#   c-blosc2           conda-forge/linux-64::c-blosc2-2.14.3-hb4ffafa_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cairo              conda-forge/linux-64::cairo-1.18.0-h3faef2a_0
#   charls             conda-forge/linux-64::charls-2.4.2-h59595ed_0
#   click              conda-forge/noarch::click-8.1.8-pyh707e725_0
#   cloudpickle        conda-forge/noarch::cloudpickle-3.1.0-pyhd8ed1ab_2
#   coin-or-cbc        conda-forge/linux-64::coin-or-cbc-2.10.12-h8b142ea_1
#   coin-or-cgl        conda-forge/linux-64::coin-or-cgl-0.60.7-h516709c_0
#   coin-or-clp        conda-forge/linux-64::coin-or-clp-1.17.8-h1ee7a9c_0
#   coin-or-osi        conda-forge/linux-64::coin-or-osi-0.108.10-haf5fa05_0
#   coin-or-utils      conda-forge/linux-64::coin-or-utils-2.11.11-hee58242_0
#   coincbc            conda-forge/noarch::coincbc-2.10.12-1_metapackage
#   contourpy          conda-forge/linux-64::contourpy-1.3.1-py310h3788b33_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   cytoolz            conda-forge/linux-64::cytoolz-1.0.1-py310ha75aee5_0
#   dask               conda-forge/noarch::dask-2024.12.1-pyhd8ed1ab_0
#   dask-core          conda-forge/noarch::dask-core-2024.12.1-pyhd8ed1ab_0
#   dask-expr          conda-forge/noarch::dask-expr-1.1.21-pyhd8ed1ab_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   distributed        conda-forge/noarch::distributed-2024.12.1-pyhd8ed1ab_0
#   dnspython          conda-forge/noarch::dnspython-2.6.1-pyhd8ed1ab_1
#   docstring_parser   conda-forge/noarch::docstring_parser-0.16-pyhd8ed1ab_0
#   email-validator    conda-forge/noarch::email-validator-2.2.0-pyhd8ed1ab_1
#   email_validator    conda-forge/noarch::email_validator-2.2.0-hd8ed1ab_1
#   et_xmlfile         conda-forge/noarch::et_xmlfile-2.0.0-pyhd8ed1ab_1
#   expat              conda-forge/linux-64::expat-2.6.4-h5888daf_0
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.55.3-py310h89163eb_1
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   fsspec             conda-forge/noarch::fsspec-2024.12.0-pyhd8ed1ab_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   gettext            conda-forge/linux-64::gettext-0.22.5-he02047a_3
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.22.5-he02047a_3
#   gflags             conda-forge/linux-64::gflags-2.2.2-h5888daf_1005
#   giflib             conda-forge/linux-64::giflib-5.2.2-hd590300_0
#   glog               conda-forge/linux-64::glog-0.6.0-h6f12383_0
#   glpk               conda-forge/linux-64::glpk-5.0-h445213a_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   graphviz           conda-forge/linux-64::graphviz-9.0.0-h78e8752_1
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-h280cfa0_4
#   gts                conda-forge/linux-64::gts-0.7.6-h977cf35_4
#   h5py               conda-forge/linux-64::h5py-3.12.1-nompi_py310h60e0fe6_103
#   harfbuzz           conda-forge/linux-64::harfbuzz-8.5.0-hfac3d4d_0
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_h4f84152_100
#   imagecodecs        conda-forge/linux-64::imagecodecs-2024.1.1-py310h68afbfc_3
#   imageio            conda-forge/noarch::imageio-2.36.1-pyh12aca89_1
#   imath              conda-forge/linux-64::imath-3.1.11-hfc55251_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.5.0-pyha770c72_1
#   jinja2             conda-forge/noarch::jinja2-3.1.5-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_1
#   jxrlib             conda-forge/linux-64::jxrlib-1.1-hd590300_3
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.7-py310h3788b33_0
#   lazy-loader        conda-forge/noarch::lazy-loader-0.4-pyhd8ed1ab_2
#   lazy_loader        conda-forge/noarch::lazy_loader-0.4-pyhd8ed1ab_2
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   lemon              conda-forge/linux-64::lemon-1.3.1-h6169397_8
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libabseil          conda-forge/linux-64::libabseil-20230802.1-cxx17_h59595ed_0
#   libaec             conda-forge/linux-64::libaec-1.1.3-h59595ed_0
#   libarrow           conda-forge/linux-64::libarrow-15.0.0-h84dd17c_0_cpu
#   libarrow-acero     conda-forge/linux-64::libarrow-acero-15.0.0-h59595ed_0_cpu
#   libarrow-dataset   conda-forge/linux-64::libarrow-dataset-15.0.0-h59595ed_0_cpu
#   libarrow-flight    conda-forge/linux-64::libarrow-flight-15.0.0-h120cb0d_0_cpu
#   libarrow-flight-s~ conda-forge/linux-64::libarrow-flight-sql-15.0.0-h61ff412_0_cpu
#   libarrow-gandiva   conda-forge/linux-64::libarrow-gandiva-15.0.0-hacb8726_0_cpu
#   libarrow-substrait conda-forge/linux-64::libarrow-substrait-15.0.0-h61ff412_0_cpu
#   libasprintf        conda-forge/linux-64::libasprintf-0.22.5-he8f35ee_3
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.22.5-he8f35ee_3
#   libavif16          conda-forge/linux-64::libavif16-1.1.1-h1909e37_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-26_linux64_openblas
#   libboost           conda-forge/linux-64::libboost-1.82.0-h6fcfa73_6
#   libboost-python    conda-forge/linux-64::libboost-python-1.82.0-py310hcb52e73_6
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-26_linux64_openblas
#   libcrc32c          conda-forge/linux-64::libcrc32c-1.1.2-h9c3ff4c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.20-hd590300_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libexpat           conda-forge/linux-64::libexpat-2.6.4-h5888daf_0
#   libgd              conda-forge/linux-64::libgd-2.3.3-h119a65a_9
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.22.5-he02047a_3
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.22.5-he02047a_3
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hd5240d6_1
#   libglib            conda-forge/linux-64::libglib-2.80.2-hf974151_0
#   libgoogle-cloud    conda-forge/linux-64::libgoogle-cloud-2.12.0-h5206363_4
#   libgrpc            conda-forge/linux-64::libgrpc-1.59.3-hd6c4280_0
#   libhwy             conda-forge/linux-64::libhwy-1.1.0-h00ab1b0_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   libjxl             conda-forge/linux-64::libjxl-0.10.3-h66b40c8_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-26_linux64_openblas
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-26_linux64_openblas
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   libllvm15          conda-forge/linux-64::libllvm15-15.0.7-hb3ce162_4
#   libnl              conda-forge/linux-64::libnl-3.11.0-hb9d3cd8_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.28-pthreads_h94d23a6_1
#   libparquet         conda-forge/linux-64::libparquet-15.0.0-h352af49_0_cpu
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-4.24.4-hf27288f_0
#   libre2-11          conda-forge/linux-64::libre2-11-2023.09.01-h7a70373_1
#   librsvg            conda-forge/linux-64::librsvg-2.56.3-he3f83f7_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libthrift          conda-forge/linux-64::libthrift-0.19.0-hb90f79a_1
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h1dd3fc0_3
#   libutf8proc        conda-forge/linux-64::libutf8proc-2.8.0-hf23e847_1
#   libwebp            conda-forge/linux-64::libwebp-1.4.0-h2c329e2_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libzopfli          conda-forge/linux-64::libzopfli-1.0.3-h9c3ff4c_0
#   llvmlite           conda-forge/linux-64::llvmlite-0.42.0-py310h1b8f574_1
#   locket             conda-forge/noarch::locket-1.0.0-pyhd8ed1ab_0
#   loguru             conda-forge/linux-64::loguru-0.7.2-py310hff52083_2
#   lz4                conda-forge/linux-64::lz4-4.3.3-py310hb259640_1
#   magicgui           conda-forge/noarch::magicgui-0.9.1-pyhd8ed1ab_1
#   markdown-it-py     conda-forge/noarch::markdown-it-py-3.0.0-pyhd8ed1ab_1
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.2-py310h89163eb_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.0-py310h68603db_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_1
#   mrcfile            conda-forge/noarch::mrcfile-1.5.3-pyhd8ed1ab_1
#   msgpack-python     conda-forge/linux-64::msgpack-python-1.1.0-py310h3788b33_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   networkx           conda-forge/noarch::networkx-3.4.2-pyh267e887_2
#   nifty              conda-forge/linux-64::nifty-1.2.1-py310h16739e1_4
#   numba              conda-forge/linux-64::numba-0.59.1-py310h7dc5dd1_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py310hb13e2d6_0
#   openexr            conda-forge/linux-64::openexr-3.2.2-haf962dd_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.2-h488ebb8_0
#   openpyxl           conda-forge/linux-64::openpyxl-3.1.5-py310h0999ad4_1
#   orc                conda-forge/linux-64::orc-1.9.2-h4b38347_0
#   pandas             conda-forge/linux-64::pandas-2.2.3-py310h5eaa309_1
#   pango              conda-forge/linux-64::pango-1.54.0-h84a9a3c_0
#   partd              conda-forge/noarch::partd-1.4.2-pyhd8ed1ab_0
#   pcre2              conda-forge/linux-64::pcre2-10.43-hcad00b1_0
#   pillow             conda-forge/linux-64::pillow-10.3.0-py310hf73ecf8_0
#   pixman             conda-forge/linux-64::pixman-0.44.2-h29eaf8c_0
#   pooch              conda-forge/noarch::pooch-1.8.2-pyhd8ed1ab_1
#   psutil             conda-forge/linux-64::psutil-6.1.1-py310ha75aee5_0
#   psygnal            conda-forge/noarch::psygnal-0.11.1-pyhd8ed1ab_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyarrow            conda-forge/linux-64::pyarrow-15.0.0-py310hf9e7431_0_cpu
#   pyconify           conda-forge/noarch::pyconify-0.2-pyhd8ed1ab_0
#   pydantic           conda-forge/noarch::pydantic-2.10.5-pyh3cfb1c2_0
#   pydantic-core      conda-forge/linux-64::pydantic-core-2.27.2-py310h505e2c1_0
#   pydantic-settings  conda-forge/noarch::pydantic-settings-2.7.1-pyh3cfb1c2_0
#   pygments           conda-forge/noarch::pygments-2.19.1-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.2.1-pyhd8ed1ab_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhff2d567_1
#   python-dotenv      conda-forge/noarch::python-dotenv-1.0.1-pyhd8ed1ab_1
#   python-elf         conda-forge/noarch::python-elf-0.6.0-pyhd8ed1ab_1
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.2-pyhd8ed1ab_1
#   pytz               conda-forge/noarch::pytz-2024.1-pyhd8ed1ab_0
#   pywavelets         conda-forge/linux-64::pywavelets-1.8.0-py310hf462985_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py310ha75aee5_1
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   qtpy               conda-forge/noarch::qtpy-2.4.2-pyhd8ed1ab_1
#   rav1e              conda-forge/linux-64::rav1e-0.6.6-he8a937b_2
#   rdma-core          conda-forge/linux-64::rdma-core-54.0-h5888daf_0
#   re2                conda-forge/linux-64::re2-2023.09.01-h7f4b329_1
#   rich               conda-forge/noarch::rich-13.9.4-pyhd8ed1ab_1
#   ruyaml             conda-forge/noarch::ruyaml-0.91.0-pyhd8ed1ab_1
#   s2n                conda-forge/linux-64::s2n-1.4.1-h06160fa_0
#   scikit-image       conda-forge/linux-64::scikit-image-0.25.0-py310h5eaa309_1
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.6.1-py310h27f47ee_0
#   scipy              conda-forge/linux-64::scipy-1.15.1-py310hfa6ec8c_0
#   six                conda-forge/noarch::six-1.17.0-pyhd8ed1ab_0
#   skan               conda-forge/noarch::skan-0.12.1-pyhd8ed1ab_0
#   snappy             conda-forge/linux-64::snappy-1.1.10-hdb0a2a9_1
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_1
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_0
#   superqt            conda-forge/noarch::superqt-0.7.0-pyhb6d5dde_0
#   svt-av1            conda-forge/linux-64::svt-av1-2.3.0-h5888daf_0
#   tblib              conda-forge/noarch::tblib-3.0.0-pyhd8ed1ab_1
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.5.0-pyhc1e730c_0
#   tifffile           conda-forge/noarch::tifffile-2024.12.12-pyhd8ed1ab_0
#   toolz              conda-forge/noarch::toolz-1.0.0-pyhd8ed1ab_1
#   tornado            conda-forge/linux-64::tornado-6.4.2-py310ha75aee5_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.12.2-hd8ed1ab_1
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_1
#   ucx                conda-forge/linux-64::ucx-1.15.0-ha691c75_8
#   unicodedata2       conda-forge/linux-64::unicodedata2-16.0.0-py310ha75aee5_0
#   vigra              conda-forge/linux-64::vigra-1.11.2-py310h53e871b_5
#   wrapt              conda-forge/linux-64::wrapt-1.17.1-py310ha75aee5_0
#   xarray             conda-forge/noarch::xarray-2025.1.1-pyhd8ed1ab_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-hb9d3cd8_1003
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.5-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.9-h8ee46fc_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-hb9d3cd8_1003
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-hb9d3cd8_1004
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-hb9d3cd8_1008
#   xyzservices        conda-forge/noarch::xyzservices-2024.9.0-pyhd8ed1ab_1
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   z5py               conda-forge/linux-64::z5py-2.0.17-py310h1a603b2_0
#   zfp                conda-forge/linux-64::zfp-1.0.1-h5888daf_2
#   zict               conda-forge/noarch::zict-3.0.0-pyhd8ed1ab_1
#   zipp               conda-forge/noarch::zipp-3.21.0-pyhd8ed1ab_1
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#   zlib-ng            conda-forge/linux-64::zlib-ng-2.0.7-h0b41bf4_0
#
#
#
# Downloading and Extracting Packages:
# libgoogle-cloud-2.12 | 41.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pillow-10.3.0        | 39.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libllvm15-15.0.7     | 31.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 9.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# vigra-1.11.2         | 6.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.15.0           | 6.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.59.3       | 6.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.56.3       | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.6.2          | 4.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :   0% 0.0003767140154306512/1 [00:00<09:39, 579.41s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :   0% 0.0007106708591504924/1 [00:00<05:28, 328.30s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :   0% 0.0004916951860778477/1 [00:00<08:22, 503.08s/it]
# pillow-10.3.0        | 39.8 MB   | :   0% 0.00039211863560808174/1 [00:00<11:03, 663.51s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :   6% 0.058390672391750935/1 [00:00<00:04,  4.34s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  10% 0.09594056598531647/1 [00:00<00:02,  2.75s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :   5% 0.05113629935209616/1 [00:00<00:05,  5.36s/it]
# pillow-10.3.0        | 39.8 MB   | :   3% 0.03136949084864654/1 [00:00<00:08,  9.03s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :  14% 0.1397608997247716/1 [00:00<00:01,  2.27s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  26% 0.2615268761673812/1 [00:00<00:00,  1.24s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :  17% 0.1691431440107796/1 [00:00<00:01,  1.90s/it]
# pillow-10.3.0        | 39.8 MB   | :  13% 0.13488881064918012/1 [00:00<00:02,  2.40s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :  21% 0.20643928045599685/1 [00:00<00:01,  1.95s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  42% 0.42071714861709153/1 [00:00<00:00,  1.04it/s]
#
# libllvm15-15.0.7     | 31.8 MB   | :  26% 0.25813997269087/1 [00:00<00:01,  1.57s/it]
# pillow-10.3.0        | 39.8 MB   | :  22% 0.21644948685566112/1 [00:00<00:01,  1.87s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :  32% 0.3198301991006229/1 [00:00<00:00,  1.42s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :  40% 0.3958146247926674/1 [00:00<00:00,  1.16s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  62% 0.6161516348834769/1 [00:00<00:00,  1.28it/s]
# libgoogle-cloud-2.12 | 41.5 MB   | :  41% 0.41438541697371634/1 [00:00<00:00,  1.28s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  48% 0.4761517722339767/1 [00:00<00:00,  1.04s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  80% 0.796662033107702/1 [00:00<00:00,  1.44it/s]
#
# libllvm15-15.0.7     | 31.8 MB   | :  53% 0.5305391057779977/1 [00:00<00:00,  1.01s/it]
# pillow-10.3.0        | 39.8 MB   | :  44% 0.4403492277878758/1 [00:00<00:00,  1.29s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :  50% 0.49763921438389025/1 [00:00<00:00,  1.36s/it]
#
#
#
# libarrow-15.0.0      | 22.0 MB   | :  95% 0.9515882804025093/1 [00:00<00:00,  1.36it/s]
#
# libllvm15-15.0.7     | 31.8 MB   | :  64% 0.6377286563429684/1 [00:00<00:00,  1.08s/it]
# pillow-10.3.0        | 39.8 MB   | :  52% 0.5230862599011811/1 [00:00<00:00,  1.38s/it]
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | :  58% 0.5752423015626044/1 [00:00<00:00,  1.42s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :  74% 0.736067693558538/1 [00:01<00:00,  1.14s/it]
# libgoogle-cloud-2.12 | 41.5 MB   | :  65% 0.6532221027567492/1 [00:01<00:00,  1.38s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  84% 0.8367781964505295/1 [00:01<00:00,  1.00s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | :  84% 0.8378485970766525/1 [00:01<00:00,  1.10s/it]
# libgoogle-cloud-2.12 | 41.5 MB   | :  73% 0.7323320459971859/1 [00:01<00:00,  1.36s/it]
#
#
# libllvm14-14.0.6     | 30.0 MB   | :  97% 0.9679150779838215/1 [00:01<00:00,  1.07it/s]
#
# libllvm15-15.0.7     | 31.8 MB   | :  94% 0.9420879765251562/1 [00:01<00:00,  1.06s/it]
# libgoogle-cloud-2.12 | 41.5 MB   | :  81% 0.8072981350678855/1 [00:01<00:00,  1.40s/it]
# libgoogle-cloud-2.12 | 41.5 MB   | :  89% 0.8905519324780594/1 [00:01<00:00,  1.34s/it]
# libgoogle-cloud-2.12 | 41.5 MB   | : 100% 0.9986688549066564/1 [00:01<00:00,  1.19s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :   0% 0.000888683400138271/1 [00:01<29:42, 1784.36s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :  21% 0.21239533263304677/1 [00:01<00:04,  5.71s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :  37% 0.3679149276572442/1 [00:01<00:01,  3.12s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :   0% 0.0010622598787931913/1 [00:01<29:10, 1752.39s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :  55% 0.5527610748860046/1 [00:01<00:00,  1.92s/it]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | :   0% 0.0012589298420159843/1 [00:01<25:27, 1529.82s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :  20% 0.1986425973343268/1 [00:01<00:05,  7.10s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :  75% 0.7464940561161476/1 [00:01<00:00,  1.34s/it]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | :  21% 0.20772342393263743/1 [00:02<00:05,  6.99s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :  41% 0.4100323132141719/1 [00:02<00:01,  3.10s/it]
#
#
#
#
# scipy-1.15.1         | 17.6 MB   | :  97% 0.9686649061507153/1 [00:02<00:00,  1.01it/s]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | :  52% 0.5174201650685696/1 [00:02<00:01,  2.47s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :  61% 0.6129239500636714/1 [00:02<00:00,  1.93s/it]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | :  85% 0.8535544328868374/1 [00:02<00:00,  1.37s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | :  89% 0.8922982981862807/1 [00:02<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 9.0 MB    | :   0% 0.001730278479365711/1 [00:02<22:15, 1337.76s/it]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | :   0% 0.0015124206530714353/1 [00:02<25:35, 1538.13s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 9.0 MB    | :  37% 0.37374015154299356/1 [00:02<00:02,  4.62s/it]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | :  29% 0.2873599240835727/1 [00:02<00:04,  6.03s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 9.0 MB    | :  73% 0.7267169613335986/1 [00:02<00:00,  2.13s/it]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | :  63% 0.6291669916777171/1 [00:02<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :   0% 0.002215537266434854/1 [00:02<19:20, 1162.81s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0.002337542641177788/1 [00:02<18:30, 1113.32s/it]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | :  97% 0.9664367973126471/1 [00:02<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :  66% 0.6602301053975864/1 [00:02<00:00,  2.89s/it]
#
#
#
#
#
#
#
#
#
#
#
# vigra-1.11.2         | 6.7 MB    | :   0% 0.0023411607321728698/1 [00:02<19:07, 1150.65s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  59% 0.5890607455768027/1 [00:02<00:01,  3.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.15.0           | 6.5 MB    | :   0% 0.002394619355785423/1 [00:02<19:27, 1170.02s/it]
#
#
#
#
#
#
#
#
#
#
#
# vigra-1.11.2         | 6.7 MB    | :  52% 0.5150553610780314/1 [00:02<00:01,  3.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.15.0           | 6.5 MB    | :  57% 0.5699194066769308/1 [00:02<00:01,  3.62s/it]
#
#
#
#
#
#
#
#
#
#
#
# vigra-1.11.2         | 6.7 MB    | :  81% 0.8100416133318129/1 [00:02<00:00,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.59.3       | 6.3 MB    | :   0% 0.0024823745949323437/1 [00:02<19:47, 1190.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :   0% 0.0025290819728815235/1 [00:02<19:31, 1174.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.56.3       | 5.6 MB    | :   0% 0.002778017041126996/1 [00:03<18:05, 1088.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.59.3       | 6.3 MB    | :  59% 0.5908051535938978/1 [00:03<00:01,  3.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | :  51% 0.5108745585220678/1 [00:03<00:02,  4.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.56.3       | 5.6 MB    | :  41% 0.4055904880045414/1 [00:03<00:03,  5.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0.0029369833860743893/1 [00:03<17:48, 1071.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.6.2          | 4.6 MB    | :   0% 0.0033863560688093333/1 [00:03<15:42, 945.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  65% 0.64907332832244/1 [00:03<00:01,  3.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.6.2          | 4.6 MB    | :  72% 0.7246801987251973/1 [00:03<00:00,  3.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libarrow-15.0.0      | 22.0 MB   | : 100% 1.0/1 [00:07<00:00,  1.36it/s]
#
#
# libllvm14-14.0.6     | 30.0 MB   | : 100% 1.0/1 [00:07<00:00,  1.07it/s]
# pillow-10.3.0        | 39.8 MB   | : 100% 1.0/1 [00:10<00:00,  1.10s/it]
#
# libllvm15-15.0.7     | 31.8 MB   | : 100% 1.0/1 [00:10<00:00,  1.06s/it]
#
#
#
#
#
# rav1e-0.6.6          | 14.7 MB   | : 100% 1.0/1 [00:10<00:00,  1.21s/it]
#
#
#
#
# libgoogle-cloud-2.12 | 41.5 MB   | : 100% 1.0/1 [00:13<00:00,  1.19s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 9.0 MB    | : 100% 1.0/1 [00:14<00:00,  2.13s/it]
#
#
#
#
#
#
# pandas-2.2.3         | 12.4 MB   | : 100% 1.0/1 [00:16<00:00,  1.37s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:16<00:00, 18.15s/it]
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:16<00:00, 18.15s/it]
#
#
#
#
#
#
#
# scikit-image-0.25.0  | 10.3 MB   | : 100% 1.0/1 [00:17<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | : 100% 1.0/1 [00:17<00:00,  2.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.15.0           | 6.5 MB    | : 100% 1.0/1 [00:17<00:00, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.15.0           | 6.5 MB    | : 100% 1.0/1 [00:17<00:00, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
#
# vigra-1.11.2         | 6.7 MB    | : 100% 1.0/1 [00:17<00:00,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | : 100% 1.0/1 [00:18<00:00, 19.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | : 100% 1.0/1 [00:18<00:00, 19.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.59.3       | 6.3 MB    | : 100% 1.0/1 [00:18<00:00, 20.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.59.3       | 6.3 MB    | : 100% 1.0/1 [00:18<00:00, 20.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.56.3       | 5.6 MB    | : 100% 1.0/1 [00:18<00:00, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.56.3       | 5.6 MB    | : 100% 1.0/1 [00:18<00:00, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | : 100% 1.0/1 [00:18<00:00,  3.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.6.2          | 4.6 MB    | : 100% 1.0/1 [00:19<00:00,  3.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# |
# /
# done

# %%
# !python3 -m venv myenv  # Create a new environment named 'myenv'
# !source myenv/bin/activate  # Activate the environment

# !pip install kornia-rs
# !pip install --upgrade pip setuptools
# !pip install --no-cache-dir kornia-rs
# !pip install kornia-rs  # Install kornia-rs first
#!pip install kornia[build]   # Then install kornia with build dependencies
# Out:
# Collecting kornia-rs
#   Using cached kornia_rs-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Using cached kornia_rs-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Installing collected packages: kornia-rs
# Successfully installed kornia-rs-0.1.8
# Requirement already satisfied: pip in /usr/local/lib/python3.10/site-packages (23.3.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (68.2.2)
# Collecting setuptools
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.8 MB/s eta 0:00:00
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# Successfully installed pip-24.3.1 setuptools-75.8.0
# Requirement already satisfied: kornia-rs in /usr/local/lib/python3.10/site-packages (0.1.8)
# Requirement already satisfied: kornia-rs in /usr/local/lib/python3.10/site-packages (0.1.8)

# %%
# use pip to install dependencies that need pytorch, including torch-em
# !pip install --no-deps kornia[build]
# !pip install --upgrade kornia
# !pip install --no-deps git+https://github.com/constantinpape/torch-em
# !pip install elf

#!pip install torch==1.13.1
# Out:
# Collecting kornia[build]
#   Using cached kornia-0.8.0-py2.py3-none-any.whl.metadata (17 kB)
# Using cached kornia-0.8.0-py2.py3-none-any.whl (1.1 MB)
# Installing collected packages: kornia
# Successfully installed kornia-0.8.0
# Requirement already satisfied: kornia in /usr/local/lib/python3.10/site-packages (0.8.0)
# Requirement already satisfied: kornia_rs>=0.1.0 in /usr/local/lib/python3.10/site-packages (from kornia) (0.1.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/site-packages (from kornia) (23.2)
# Collecting torch>=1.9.1 (from kornia)
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting filelock (from torch>=1.9.1->kornia)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/site-packages (from torch>=1.9.1->kornia) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/site-packages (from torch>=1.9.1->kornia) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/site-packages (from torch>=1.9.1->kornia) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/site-packages (from torch>=1.9.1->kornia) (2024.12.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.9.1->kornia)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.9.1->kornia)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.9.1->kornia)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=1.9.1->kornia)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.9.1->kornia)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=1.9.1->kornia)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=1.9.1->kornia)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.9.1->kornia)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2->torch>=1.9.1->kornia) (3.0.2)
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 26.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 59.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 146.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 176.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 31.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 72.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 64.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 64.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 70.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 70.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 104.4 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 72.5 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 22.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
# Successfully installed filelock-3.16.1 mpmath-1.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.1 triton-3.1.0
# Collecting git+https://github.com/constantinpape/torch-em
#   Cloning https://github.com/constantinpape/torch-em to /tmp/pip-req-build-gik98yb6
#   Running command git clone --filter=blob:none --quiet https://github.com/constantinpape/torch-em /tmp/pip-req-build-gik98yb6
#   Resolved https://github.com/constantinpape/torch-em to commit ace81606fdb4506254ce2283fc0c6ef1574fe465
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: torch_em
#   Building wheel for torch_em (pyproject.toml) ... done
#   Created wheel for torch_em: filename=torch_em-0.7.5-py3-none-any.whl size=480720 sha256=062b48fab0b6e503c45c003d3e33bc45b1116980fee81645413526a98d816bab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r45p2ysu/wheels/36/b0/30/631438ed0f235a8c71b1d753a0a88b4301a29d2d37b1976923
# Successfully built torch_em
# Installing collected packages: torch_em
# Successfully installed torch_em-0.7.5
# Requirement already satisfied: elf in /usr/local/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from elf) (1.26.4)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/site-packages (from elf) (2.36.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/site-packages (from elf) (0.25.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/site-packages (from elf) (1.6.1)
# Requirement already satisfied: skan in /usr/local/lib/python3.10/site-packages (from elf) (0.12.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/site-packages (from imageio->elf) (10.3.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/site-packages (from scikit-image->elf) (1.15.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/site-packages (from scikit-image->elf) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/site-packages (from scikit-image->elf) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/site-packages (from scikit-image->elf) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/site-packages (from scikit-image->elf) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn->elf) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn->elf) (3.5.0)
# Requirement already satisfied: magicgui>=0.7.3 in /usr/local/lib/python3.10/site-packages (from skan->elf) (0.9.1)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/site-packages (from skan->elf) (3.10.0)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/site-packages (from skan->elf) (0.59.1)
# Requirement already satisfied: pandas>=2.0.2 in /usr/local/lib/python3.10/site-packages (from skan->elf) (2.2.3)
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.10/site-packages (from skan->elf) (3.1.5)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/site-packages (from skan->elf) (1.0.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/site-packages (from skan->elf) (4.66.1)
# Requirement already satisfied: docstring-parser>=0.7 in /usr/local/lib/python3.10/site-packages (from magicgui>=0.7.3->skan->elf) (0.16)
# Requirement already satisfied: psygnal>=0.6.1 in /usr/local/lib/python3.10/site-packages (from magicgui>=0.7.3->skan->elf) (0.11.1)
# Requirement already satisfied: qtpy>=1.7.0 in /usr/local/lib/python3.10/site-packages (from magicgui>=0.7.3->skan->elf) (2.4.2)
# Requirement already satisfied: superqt>=0.6.1 in /usr/local/lib/python3.10/site-packages (from superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/site-packages (from magicgui>=0.7.3->skan->elf) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.4->skan->elf) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /usr/local/lib/python3.10/site-packages (from numba>=0.53->skan->elf) (0.42.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/site-packages (from openpyxl>=2.6->skan->elf) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=2.0.2->skan->elf) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas>=2.0.2->skan->elf) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.4->skan->elf) (1.17.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/site-packages (from superqt>=0.6.1->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (2.19.1)
# Requirement already satisfied: pyconify>=0.1.4 in /usr/local/lib/python3.10/site-packages (from superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from pyconify>=0.1.4->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests->pyconify>=0.1.4->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->pyconify>=0.1.4->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests->pyconify>=0.1.4->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests->pyconify>=0.1.4->superqt[iconify]>=0.6.1->magicgui>=0.7.3->skan->elf) (2024.12.14)

# %%
# mount your google drive to permanently save data
from google.colab import drive
drive.mount("/content/drive")

# test if data path is correct by editing path below
# !ls /content/drive/MyDrive/training_data/train/raw_images/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# s300-1-raw.tif

# %% [markdown]
# ## Imports
#
# Import the required libraries, no need to change anything here.

# %%
# load tensorboard extension
# we will need this later in the notebook to monitor the training progress
# %load_ext tensorboard

# %%
import numpy as np
import torch.nn as nn
import torch_em
import torch_em.data.datasets as torchem_data
from torch_em.model import UNet2d
from torch_em.util.debug import check_loader, check_trainer

# %% [markdown]
# ## Training Data
#
# Choose the dataset for training. You have two options here: choose a preconfigured dataset or specify the filepaths to your training data.
#
# For preconfigured datasets `torch_em` implements download and default pre-processing already. The following pre-configured datasets are currently available:
# - `covid_if`: Cells imaged via immunofluorescence.
# - `dsb`: Nuclei imaged via fluorescence.
# - `hpa`: Data from the human protein atlas.
# - `isbi2012`: Neural tissue imaged in electron microscopy.
# - `livecell`: Cells imaged in phase-contrast microscopy.
# - `vnc-mitos`: Mitochondria imaged in electron microscopy.
#
# If you're unsure if one of these datasets is suitable for you, just select it and continue to `Check training data` with the default settings in the next sections. You will see example images from the data there.
#
# You can also load the training data from local files. `torch_em` supports loading data from different formats, the two easiest options are:
# - single images: store images and labels in two separate folder using a common image format such as png or tif. The corresponding data and label files should have the same filename.
#     - set `data_paths` to the filepath of the folder with the images, `label_paths` to the path of the folder with the labels
#     - set `data_key` and `label_key` to `*.<FILE_EXTENSION>`, e.g. `*.tif` for tif files.
# - image stacks: store the image and label stack(s) as hdf5, zarr or n5 data.
#     - set `data_paths` to the filepath of the image data stack and `label_paths` to the path of the label data stack; you can also provide a list of file paths if you have multiple stacks
#     - set `data_key` and `label_key` to the corresponding paths in file.
#
# You can find examples for the custom datasets in the comments below.
#
# You also need to choose `patch_shape`, which determines the size of the patches used for training, here.

# %%
# CONFIGURE ME

#
# use a pre-configured dataset
#

# Specify a pre-configured dataset. Set to `None` in order to specify the training data via file-paths instead.
preconfigured_dataset = None

# example: use the pre-configured `dsb` dataset
# preconfigured_dataset = "dsb"

# Where to download the training data (the data will be downloaded only once).
# If you work in google colab you may want to adapt this path to be on your google drive, in order
# to not loose the data after each session.
#download_folder = f"/content/drive/My Drive/training_data"
data_path = '/content/drive/MyDrive/training_data'

#
# use a custom dataset
#

# Create a custom dataset from local data by specifiying the paths for training data, training labels
# as well as validation data and validation labels

train_data_paths = f"{data_path}/train/raw_images/"
val_data_paths = f"{data_path}/test/raw_images/"
data_key = "*.tif"
train_label_paths = f"{data_path}/train/masks/"
val_label_paths = f"{data_path}/test/masks/"
label_key = "*.tif"

# In addition you can also specify region of interests for training using the normal python slice syntax
train_rois = None
val_rois = None

# example 1: Use training raw data and labels stored as tif-images in separate folders.
# The example is formulated using the data from the `dsb` dataset.

# train_data_paths = "./training_data/dsb/train/images"
# val_data_paths = "./training_data/dsb/test/images"
# data_key = "*.tif"
# train_label_paths = "./training_data/dsb/train/masks"
# val_label_paths = "./training_data/dsb/test/masks"
# label_key = "*.tif"
# patch_shape = (256, 256)

# example 2: Use training data and labels stored as a single stack in an hdf5 file.
# This example is formulated using the data from the `vnc-mitos` dataset,
# which stores the raw data in `/raw` and the labels in `/labels/mitochondria`.
# Note that we use roi's here to get separate training and val data from the same file.
# train_data_paths etc. can also be lists in order to train from multiple stacks.

# train_data_paths = train_label_paths = val_data_paths = val_label_paths = "./training_data/vnc-mitos/vnc_train.h5"
# data_key = "/raw"
# label_key = "/labels/mitochondria"
# train_rois = np.s_[:18, :, :]
# val_rois = np.s_[18:, :, :]
# patch_shape = (1, 512, 512)

#
# choose the patch shape
#

# This should be chosen s.t. it is smaller than the smallest image in your training data.
# If you are training from 3d data (data with a z-axis), you will need to specify the patch_shape
# as (1, shape_y, shape_x).
patch_shape = (1, 102, 117)

# %%
import numpy as np
import tifffile
import os

def add_channel_dimension_and_save_as_tiff(folder):
    files = [f for f in os.listdir(folder) if f.endswith('.tif')]
    for file in files:
        path = os.path.join(folder, file)
        # Read the image
        image = tifffile.imread(path)
        # Add channel dimension
        image = np.expand_dims(image, axis=0)  # Shape becomes (1, height, width)
        # Remove any unnecessary singleton dimensions
        image = np.squeeze(image, axis=0)  # Now shape becomes (height, width)
        # Save with channel dimension intact
        tifffile.imwrite(path, image)

# Add channel dimension to raw images and masks
add_channel_dimension_and_save_as_tiff("/content/drive/MyDrive/training_data/train/raw_images")
add_channel_dimension_and_save_as_tiff("/content/drive/MyDrive/training_data/train/masks")

# %%
import imageio

# Load a sample raw image and mask
raw_sample = imageio.imread('/content/drive/MyDrive/training_data/train/raw_images/s300-1-raw.tif')
mask_sample = imageio.imread('/content/drive/MyDrive/training_data/train/masks/s300-1-mask.tif')

print(f"Raw image shape: {raw_sample.shape}")
print(f"Mask shape: {mask_sample.shape}")
# Out:
# Raw image shape: (1, 102, 117)
# Mask shape: (1, 102, 117)
# <ipython-input-83-27c2a2131e2e>:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   raw_sample = imageio.imread('/content/drive/MyDrive/training_data/train/raw_images/s300-1-raw.tif')
# <ipython-input-83-27c2a2131e2e>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask_sample = imageio.imread('/content/drive/MyDrive/training_data/train/masks/s300-1-mask.tif')

# %%
dataset_names = [
    "covid_if", "dsb", "hpa", "isbi2012", "livecell", "vnc-mitos"
]


def check_data(data_paths, label_paths, rois):
    print("Loading the raw data from:", data_paths, data_key)
    print("Loading the labels from:", label_paths, label_key)
    try:
        torch_em.default_segmentation_dataset(
            data_paths, data_key, label_paths, label_key,
            patch_shape, rois=rois, ndim=2 # Explicitly specifying ndim=2 for 2D data
        )
    except Exception as e:
        print("Loading the dataset failed with:")
        raise e

if preconfigured_dataset is None:
    print("Using a custom dataset:")
    print("Checking the training dataset:")
    check_data(train_data_paths, train_label_paths, train_rois)
    check_data(val_data_paths, val_label_paths, val_rois)
else:
    assert preconfigured_dataset in dataset_names, f"Invalid pre-configured dataset: {preconfigured_dataset}, choose one of {dataset_names}."
    if preconfigured_dataset in ("isbi2012", "vnc-mitos") and len(patch_shape) == 2:
        patch_shape = (1,) + patch_shape

assert len(patch_shape) in (2, 3)
# Out:
# Using a custom dataset:
# Checking the training dataset:
# Loading the raw data from: /content/drive/MyDrive/training_data/train/raw_images/ *.tif
# Loading the labels from: /content/drive/MyDrive/training_data/train/masks/ *.tif
# Loading the raw data from: /content/drive/MyDrive/training_data/test/raw_images/ *.tif
# Loading the labels from: /content/drive/MyDrive/training_data/test/masks/ *.tif

# %% [markdown]
# ## Network output
#
# Choose the transformations applied to your label data in order to generate the network target data. If your labels can be fed to the network directly you don't need to do anything here. Otherwise, you can choose between the following transformations:
# - `foreground`: transforms labels into a binary target
# - `affinities`: transforms labels into affinity target
# - `boundaries`: transforms labels into boundary target
#
# Note that `affinities` and `boundaries` are mutually exclusive; `foreground` can be combined with the two other transformations. All three transformations are implemented to be applied to *instance labels*. See the screenshot below for an illustration of the expected input and the result of these transformations. You will see their result for your own datain in `Check training data`.
#
# ![targets](https://github.com/constantinpape/torch-em/blob/main/experiments/misc/targets.png?raw=1)

# %%
# CONFIGURE ME

# Whether to add a foreground channel (1 for all labels that are not zero) to the target.
foreground = False
# Whether to add affinity channels (= directed boundaries) or a boundary channel to the target.
# Note that you can choose at most of these two options.
affinities = False
boundaries = False

# the pixel offsets that are used to compute the affinity channels
offsets = [[-1, 0], [0, -1], [-3, 0], [0, -3], [-9, 0], [0, -9]]

# %%
assert not (affinities and boundaries), "Predicting both affinities and boundaries is not supported"

label_transform, label_transform2 = None, None
if affinities:
    label_transform2 = torch_em.transform.label.AffinityTransform(
        offsets=offsets, add_binary_target=foreground, add_mask=True
    )
elif boundaries:
    label_transform = torch_em.transform.label.BoundaryTransform(
        add_binary_target=foreground
    )
elif foreground:
    label_transform = torch_em.transform.label.labels_to_binary

# %% [markdown]
# ## Loss, metric & batch size
#
# Choose important training parameters:
#
# - `loss`: the loss function; can be one of `"bce", "ce", "dice"` (binary cross entropy, cross entropy, dice) or a torch module
# - `metric`: the metric used for the validation data; same options as for `loss`
# - `batch_size`: the training batch size
#
# If you're unsure about these settings just use the default values, they are probably ok.

# %%
# CONFIGURE ME
batch_size = 1
loss = "dice"
metric = "dice"

# %%
def get_loss(loss_name):
    loss_names = ["bce", "ce", "dice"]
    if isinstance(loss_name, str):
        assert loss_name in loss_names, f"{loss_name}, {loss_names}"
        if loss_name == "dice":
            loss_function = torch_em.loss.DiceLoss()
        elif loss == "ce":
            loss_function = nn.CrossEntropyLoss()
        elif loss == "bce":
            loss_function = nn.BCEWithLogitsLoss()
    else:
        loss_function = loss_name

    # we need to add a loss wrapper for affinities
    if affinities:
        loss_function = torch_em.loss.LossWrapper(
            loss_function, transform=torch_em.loss.ApplyAndRemoveMask()
        )
    return loss_function


loss_function = get_loss(loss)
metric_function = get_loss(metric)

kwargs = dict(
    ndim=2, patch_shape=patch_shape, batch_size=batch_size,
    label_transform=label_transform, label_transform2=label_transform2
)
ds = preconfigured_dataset

if ds is None:
    train_loader = torch_em.default_segmentation_loader(
        train_data_paths, data_key, train_label_paths, label_key,
        rois=train_rois, **kwargs
    )
    val_loader = torch_em.default_segmentation_loader(
        val_data_paths, data_key, val_label_paths, label_key,
        rois=val_rois, **kwargs
    )
else:
    kwargs.update(dict(download=True))
    if ds == "covid_if":
        # use first 5 images for validation and the rest for training
        train_range, val_range = (5, None), (0, 5)
        train_loader = torchem_data.get_covid_if_loader(download_folder, sample_range=train_range, **kwargs)
        val_loader = torchem_data.get_covid_if_loader(download_folder, sample_range=val_range, **kwargs)
    elif ds == "dsb":
        train_loader = torchem_data.get_dsb_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_dsb_loader(download_folder, split="train", **kwargs)
    elif ds == "hpa":
        train_loader = torchem_data.get_hpa_segmentation_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_hpa_segmentation_loader(download_folder, split="val", **kwargs)
    elif ds == "isbi2012":
        assert not foreground, "Foreground prediction for the isbi neuron segmentation data does not make sense, please change these setings"
        train_roi, val_roi = np.s_[:28, :, :], np.s_[28:, :, :]
        train_loader = torchem_data.get_isbi_loader(download_folder, rois=train_roi, **kwargs)
        val_loader = torchem_data.get_isbi_loader(download_folder, rois=val_roi, **kwargs)
    elif ds == "livecell":
        train_loader = torchem_data.get_livecell_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_livecell_loader(download_folder, split="val", **kwargs)
    # monuseg is not fully implemented yet
    # elif ds == "monuseg":
    #     train_loader = torchem_data.get
    elif ds == "vnc-mitos":
        train_roi, val_roi = np.s_[:18, :, :], np.s_[18:, :, :]
        train_loader = torchem_data.get_vnc_mito_loader(download_folder, rois=train_roi, **kwargs)
        val_loader = torchem_data.get_vnc_mito_loader(download_folder, rois=val_roi, **kwargs)

assert train_loader is not None, "Something went wrong"
assert val_loader is not None, "Something went wrong"

# %% [markdown]
# ## Check training data
#
# Check the output from your data loader. It consists of the input data for your network and the target data.
# You should check that the target looks reasonable.

# %%
# CONFIGURE ME

# choose the number of samples to check per loader
n_samples = 4

# %%
print("Training samples")
check_loader(train_loader, n_samples, plt=True)
print("Validation samples")
check_loader(val_loader, n_samples, plt=True)

# %% [markdown]
# ## Network architecture
#
# Choose the important network architecture parameters for the 2d UNet:
# - `depth`: the number of decoder / encoder levels
# - `initial_features`: the number of features in the first encoder level, the number will be doubled for each level
# - `final_activation`: the activation applied to the UNet output
# - `in_channels`: the number of input channels (= number of channels of the raw data)
# - `out_channels`: the number of output channels (usually the number of target channels)
#
# If you're unsure about these settings just use the default values, they are probably ok.

# %%
# CONFIGURE ME
depth = 4
initial_features = 32
final_activation = None

# If you leave the in/out_channels as None an attempt will be made to automatically deduce these numbers.
in_channels = None
out_channels = None

# %%
if final_activation is None and loss == "dice":
    final_activation = "Sigmoid"
    print("Adding a sigmoid activation because we are using dice loss")

if in_channels is None:
    in_channels = 1

if out_channels is None:
    if affinities:
        n_off = len(offsets)
        out_channels = n_off + 1 if foreground else n_off
    elif boundaries:
        out_channels = 2 if foreground else 1
    elif foreground:
        out_channels = 1
    assert out_channels is not None, "The number of out channels could not be deduced automatically. Please set it manually in the cell above."

print("Creating 2d UNet with", in_channels, "input channels and", out_channels, "output channels.")
model = UNet2d(
    in_channels=in_channels, out_channels=out_channels, depth=depth, final_activation=final_activation
)

# %% [markdown]
# ## Tensorboard
#
# Start the tensorboard in order to keep track of the training progress.

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Training
#
# Choose additional training parameter:
# - `experiment_name`: the name for this training run, which will be used for naming the checkpoint for this model and for identifying the model in tensorboard.
# - `n_iterations`: number of iterations to train for.
# - `learning_rate`: the learning rate for gradient based updates.
#
# This also starts the training!
#
# **Important:** If you're on google colab the checkpoint will not be saved permanently. To save it you will need to copy the local folder `checkpoints` to your google drive.

# %%
# CONFIGURE ME
experiment_name = "my-shiny-net"
n_iterations = 10000
learning_rate = 1.0e-4

# %%
# IMPORTANT! if your session on google colab crashes here, you will need to uncomment the 'logger=None' comment
# in this case you can't use tensorboard, but everything else will work as expected
# (this happens due to incompatible google protobuf versions and I don't have time to fix this right now)
trainer = torch_em.default_segmentation_trainer(
    name=experiment_name, model=model,
    train_loader=train_loader, val_loader=val_loader,
    loss=loss_function, metric=metric_function,
    learning_rate=learning_rate,
    mixed_precision=True,
    log_image_interval=50,
    # logger=None
)
trainer.fit(n_iterations)

# %% [markdown]
# ## Check trained network
#
# Look at predictions from the trained network and their comparison to the target.

# %%
# CONFIGURE ME
n_samples = 2

# %%
check_trainer(trainer, n_samples, plt=True)

# %% [markdown]
# ## Export network to bioimage.io format
#
# Finally, you can export the trained model in the format compatible with [BioImage.IO](https://bioimage.io/#/), a modelzoo for bioimage analysis. After exporting, you can upload the model there to share it with other researchers.
# You only need to configure where to save the model via `export_folder` and whether to convert it to additional formats via `additional_weight_formats` and you will be prompted to enter additional information when you run the second cell. You should also write some documentation for the model in `doc`.

# %%
# CONFIGURE ME

# The folder where the bioimageio model will be saved (as a .zip file).
# If you run in google colab you should adapt this path to your google drive so that you can download the saved model.
export_folder = "./my-fancy-bio-model"

# Whether to convert the model weights to additional formats.
# Currently, torchscript and onnx are support it and this will enable running the model
# in more software tools.
additional_weight_formats = None
# additional_weight_formats = ["torchscript"]

doc = None
# write some markdown documentation like this, otherwise a default documentation text will be used
# doc = """#My Fancy Model
# This is a fancy model to segment shiny objects in images.
# """

# %%
import torch_em.util.modelzoo

for_dij = additional_weight_formats is not None and "torchscript" in additional_weight_formats

training_data = None
if preconfigured_dataset is not None:
    if preconfigured_dataset == "vnc-mitos":
        data_id = torchem_data.get_bioimageio_dataset_id("vnc")
    else:
        data_id = torchem_data.get_bioimageio_dataset_id(preconfigured_dataset)
    if data_id:
        training_data = {"id": data_id}

pred_str = ""
if affinities:
    pred_str = "affinities and foreground probabilities" if foreground else "affinities"
elif boundaries:
    pred_str = "boundary and foreground probabilities" if foreground else "boundaries"
elif foreground:
    pred_str = "foreground"

default_doc = f"""#{experiment_name}

This model was trained with [the torch_em 2d UNet notebook](https://github.com/constantinpape/torch-em/blob/main/experiments/2D-UNet-Training.ipynb).
"""
if pred_str:
    default_doc += f"It predicts {pred_str}.\n"

training_summary = torch_em.util.get_training_summary(trainer, to_md=True, lr=learning_rate)
default_doc += f"""## Training Schedule

{training_summary}
"""

if doc is None:
    doc = default_doc

torch_em.util.modelzoo.export_bioimageio_model(
    trainer, export_folder, input_optional_parameters=True,
    for_deepimagej=for_dij, training_data=training_data, documentation=doc
)
torch_em.util.modelzoo.add_weight_formats(export_folder, additional_weight_formats)
